# %% [markdown]
# ![스크린샷 2022-12-26 오후 10.34.49.png](data:image/png;base64,...)

# %% [markdown]
# ![스크린샷 2022-12-26 오후 10.39.55.png](data:image/png;base64,...)

# %% [markdown]
# ![스크린샷 2022-12-26 오후 10.40.34.png](data:image/png;base64,...)

# %% [markdown]
# #범위

# %% [markdown]
# ![스크린샷 2022-12-26 오후 10.45.46.png](data:image/png;base64,...)
