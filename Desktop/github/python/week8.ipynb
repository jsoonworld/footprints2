# %% [markdown]
# #if else, elif

# %% [markdown]
# #반복문

# %% [markdown]
# #리스트와 반복문

# %% [markdown]
# ## 배열: 길이가 고정
# ## 리스트: 배열에 요소 추가/제거 등의 기능을 추가한 것

# %% [markdown]
# #리스트 반대로 돌리기

# %%
 print("abcde"[::1])
 print("ace"[::-1])
# Out:
# abcde
# eca

# %% [markdown]
# #요소 존재를 확인하는 것 이외의 것들은 파괴적으로 존재
# #그 이유는 리스트를 남기는 것이 메모리에 어려움을 가져올 수 있기 때문

# %% [markdown]
# ![스크린샷 2022-12-26 오후 9.03.43.png](data:image/png;base64,...)

# %% [markdown]
# ![스크린샷 2022-12-26 오후 9.04.53.png](data:image/png;base64,...)

# %% [markdown]
# ![스크린샷 2022-12-26 오후 9.07.19.png](data:image/png;base64,...)

# %% [markdown]
# ![스크린샷 2022-12-26 오후 9.08.21.png](data:image/png;base64,...)

# %% [markdown]
# #반복문

# %% [markdown]
# ![스크린샷 2022-12-26 오후 9.40.46.png](data:image/png;base64,...)

# %% [markdown]
# ![스크린샷 2022-12-26 오후 9.41.51.png](data:image/png;base64,...)

# %% [markdown]
# #딕셔너리와 반복문

# %% [markdown]
# ![스크린샷 2022-12-26 오후 10.05.55.png](data:image/png;base64,...)

# %% [markdown]
# ![스크린샷 2022-12-26 오후 10.07.13.png](data:image/png;base64,...)

# %% [markdown]
# ![스크린샷 2022-12-26 오후 10.12.25.png](data:image/png;base64,...)
