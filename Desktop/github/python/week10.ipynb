# %% [markdown]
# #reversed()
# ![스크린샷 2022-12-27 오후 8.33.28.png](data:image/png;base64,...)

# %%
for i in reversed(range(0, 10)):
  print(i)
# Out:
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2
# 1
# 0

# %% [markdown]
# #while 반복문
#
# 끝이 정해져있는 것 일 때 주로 사용 ( 내일 아침까지, ~가 사라질 떄 까지,, )

# %% [markdown]
# ![스크린샷 2022-12-27 오후 8.39.37.png](data:image/png;base64,...)

# %% [markdown]
# #Break, continue

# %% [markdown]
# #max(), min() 리스트의 최대 최소 찾아주는 함수

# %% [markdown]
# #sum() 리스트 내부의 모든 값을 더해주는 함수

# %% [markdown]
# #enumerate() 리스트를 넣어면 인덱스와 함께 반환해줌

# %% [markdown]
# ![스크린샷 2022-12-27 오후 8.58.25.png](data:image/png;base64,...)

# %% [markdown]
# #items()

# %% [markdown]
# ![스크린샷 2022-12-27 오후 9.00.47.png](data:image/png;base64,...)

# %% [markdown]
# #리스트 내포 (List comprehension)

# %% [markdown]
# ![스크린샷 2022-12-27 오후 9.05.17.png](data:image/png;base64,...)

# %% [markdown]
# ![스크린샷 2022-12-27 오후 9.12.49.png](data:image/png;base64,...)

# %% [markdown]
# # "".join () 파라미터로 문자열로 이루어진 리스트를 넣어줘야 함

# %% [markdown]
# ![스크린샷 2022-12-27 오후 9.38.02.png](data:image/png;base64,...)

# %% [markdown]
# ![스크린샷 2022-12-27 오후 9.40.54.png](data:image/png;base64,...)
