# %% [markdown]
# ![스크린샷 2022-12-22 오전 11.16.16.png](data:image/png;base64,...)

# %% [markdown]
# #1. interactive shell

# %%
print("hello coding python")
print("안녕하세요")
# Out:
# hello coding python
# 안녕하세요

# %% [markdown]
# # 문장 ( statement )
# 실행할 수 있는 코드의 최소 단위
# "엔터쳐서 정상적으로 실행되면 문장"
#
# #표현식(expression)
# 어떤 값을 만들어내는 코드
#
# #리터럴 (literal )
#
# 리터럴 < 표현식 < 문장
#
# #연산자 ( operator )
#
# ##+ - * / %
# ##** //
# ##or and not in
#
# # 키워드 (keyword)
#
# 파이썬이 만들어질 때 정의된 특별한 의미를 갖는 단어
#
# Flase
# None
# raise
# True
#
# #식별자 (identifier)
#
# 기호를 빌려서 값을 표현!
#
# 파이, r, x, y 등등
#
# print 역시 식별자
